# %% [markdown]
# # Chapter 25: AI Governance & Ethics
# ## Notebook 03 — Governance in Practice
#
# Tools serve **process**. We connect risk classification and documentation to the wider landscape: regulation, accountability structures, and culture — and close the curriculum.
#
# ### What you'll learn
#
# | Topic | Section |
# |-------|--------|
# | The regulatory landscape | §1 |
# | Accountability and audits | §2 |
# | Ethical culture and what's next | §3 |
#
# **Time estimate:** 2 hours
#
# ### Key concepts
#
# - **EU AI Act / NIST AI RMF** — the leading governance frameworks.
# - **Accountability** — named owners, audit trails, incident response.
# - **Review boards** — cross-functional sign-off for high-risk systems.
# - **Culture** — governance succeeds only if the organization values it.
#
# ---
# *Generated by Berta AI*

# %% [markdown]
# ## 1-2. A governance checklist
#
# Before deployment, a high-risk system should clear a documented set of gates. We assemble one from this chapter's tools.

# %%
import sys
sys.path.insert(0, "../scripts")
from governance import classify_risk, validate_model_card

system = {"name": "resume_ranker", "domain": "employment"}
card = {"model_name": "ResumeRanker", "intended_use": "Screen applications",
        "training_data": "2024 hiring data", "metrics": "F1 0.79",
        "limitations": "Audited quarterly for bias",
        "ethical_considerations": "Human-in-the-loop required"}

checklist = {
    "risk_tier": classify_risk(system),
    "documentation_complete": validate_model_card(card)["complete"],
}
print(checklist)

# %% [markdown]
# ## 3. The end of the curriculum
#
# You've gone from Python fundamentals to building, deploying, securing, and *governing* AI systems. Responsible AI is not a final chapter you finish — it's a practice you carry into everything you build. Congratulations on completing Berta Chapters.

# %% [markdown]
# ---
#
# ## Summary
#
# Risk classification and documentation feed a governance process — regulation, accountability, audits, and culture — that decides whether a system ships responsibly. This closes the Berta curriculum.
#
# ---
# *Generated by Berta AI | Berta Chapters*
