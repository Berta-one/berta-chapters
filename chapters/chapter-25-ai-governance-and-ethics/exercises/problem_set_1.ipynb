# %% [markdown]
# # Chapter 25: AI Governance & Ethics
# ## Problem Set 1: Risk & Matrices — Problem Set
#
# Operationalize risk assessment.
#
# Work through each task in order. Try it yourself before opening the solutions notebook.
#
# ---
# *Generated by Berta AI*

# %% [markdown]
# ### Task 1: Tier the systems
#
# Assert an employment system is high-risk, a chatbot is limited, and a prohibited use is unacceptable.

# %%
def check_tiers():
    # YOUR CODE HERE
    pass

# %% [markdown]
# ### Task 2: Risk matrix levels
#
# Assert the matrix returns 'low' for (1,1) and 'critical' for (5,5).

# %%
def check_matrix():
    # YOUR CODE HERE
    pass
